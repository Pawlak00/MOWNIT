# %% [markdown]
# # Piotr Pawłowski laboratorium 3

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# zad. 1

# %%
#f(x)
def f(x):
    return 1/(1+x**2)
n=5,10,15
x = np.linspace(-5, 5, 100)
plt.plot(x,f(x))

# %%
#p(x)
def interp(n,count=30):
    results=[]
    x=np.linspace(-5,5,n+1)
    vander_x=np.vander(x,n+1,True)
    coef=np.linalg.solve(vander_x,list(map(f,x)))
    check=np.linspace(-5,5,count)
    for x in check:
        res=0
        for i,c in enumerate(coef):
            res+=c*(x**i)
        results.append(res)
    return results
plt.plot(np.linspace(-5,5,30),interp(5))
plt.plot(np.linspace(-5,5,30),interp(10))
plt.plot(np.linspace(-5,5,30),interp(15))
plt.show()
function=[]
for x in np.linspace(-5,5,30):
    function.append(f(x))
plt.plot(np.linspace(-5,5,30),function)
plt.show()

# %% [markdown]
# # Zadanie 2

# %%
from scipy import interpolate, linspace
n = 16
# x = [np.cos(np.pi*(2*k-1)/(2*n)) for k in range(1, n+1)]
# x = 5*np.array(x)
x= linspace(-5, 5, n)
y = f(x)
f = interpolate.lagrange(x, y)
xnew = linspace(-5, 5, 200) # points to plot at
ynew = f(xnew)
plt.plot(x, y, 'o', xnew, ynew, '-')

# %% [markdown]
# # Zadanie 3

# %%
a=2
b=3
def x(t):
    return a*np.cos(t)
def y(t):
    return b*np.sin(t)
ti=linspace(-5, 5, n)
xi_prev=[x(t) for t in ti]
yi_prev=[y(t) for t in ti]
plt.plot(xi_prev,yi_prev)
x_interpolated=interpolate.CubicSpline(ti,xi_prev)
y_interpolated=interpolate.CubicSpline(ti,yi_prev)
plt.plot(x_interpolated,y_interpolated)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-213-6145f501187e> in <module>
#      11 x_interpolated=interpolate.CubicSpline(ti,xi_prev)
#      12 y_interpolated=interpolate.CubicSpline(ti,yi_prev)
# ---> 13 plt.plot(x_interpolated,y_interpolated)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...
